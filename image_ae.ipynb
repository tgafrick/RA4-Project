# %%
print("Importing libraries")
import torch
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader
import numpy as np
import os
import nrrd
import pytorch_lightning as pl #python -m pip install lightning
from monai.data import CacheDataset, DataLoader
from monai.transforms import Compose, Lambda, RandSpatialCrop, RandRotate90, ToTensor, ScaleIntensityRange
from monai.networks.nets import AutoEncoder
from monai.losses import SSIMLoss
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
from pytorch_lightning.callbacks import ModelCheckpoint
import torch.nn as nn
import torch.optim.lr_scheduler as lr_scheduler
import time
print("Done importing libraries")
# Out:
# Importing libraries
# Done importing libraries

# %%
#Using AutoEncoder instead of UNet to avoid skip connections 
class SlicePlotter:
    def __init__(self):
        pass

    def plot_slices(self, original_slice, reconstruction_slice, title):
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(original_slice, cmap='gray')
        plt.title(f'Original {title} Slice')
        plt.subplot(1, 2, 2)
        plt.imshow(reconstruction_slice, cmap='gray')
        plt.title(f'Reconstructed {title} Slice')
        plt.show()

class AutoEncoderModel(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.autoencoder = AutoEncoder(
            spatial_dims=3, 
            in_channels=1,  
            out_channels=1,  
            channels=(16, 32, 64, 128, 256), 
            strides=(2, 2, 2, 2, 2), 
            kernel_size=3, 
            num_res_units=2
            
        )
        self.loss_function = SSIMLoss(spatial_dims=3)
        self.slice_plotter = SlicePlotter()

    def forward(self, x):
        return self.autoencoder(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        x = x.unsqueeze(1)  # Add channel dimension
        y = y.unsqueeze(1)  # Add channel dimension
        x_hat = self(x)
        
        # Ensure y_pred has the correct shape (batch_size, 1, height, width, depth)
        y_pred = x_hat 
        
        loss = self.loss_function(y_pred, y)
        self.log('train_loss', loss)

        if self.current_epoch % 300 == 0 and batch_idx == 0:
            for _ in range(3):  # Plot 3 random slices
                slice_idx = torch.randint(0, x.shape[2], (1,)).item()
                original_slice = x[0, 0, slice_idx, :, :].detach().cpu().numpy()
                reconstruction_slice = x_hat[0, 0, slice_idx, :, :].detach().cpu().numpy()
                self.slice_plotter.plot_slices(original_slice, reconstruction_slice, 'Train')

        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        x = x.unsqueeze(1)  # Add channel dimension
        y = y.unsqueeze(1)  # Add channel dimension
        x_hat = self(x)
        
        # Ensure y_pred has the correct shape (batch_size, 1, height, width, depth)
        y_pred = x_hat 
        
        loss = self.loss_function(y_pred, y)
        self.log('val_loss', loss)

        if self.current_epoch % 300 == 0 and batch_idx == 0:
            for _ in range(3):  # Plot 3 random slices
                slice_idx = torch.randint(0, x.shape[2], (1,)).item()
                original_slice = x[0, 0, slice_idx, :, :].detach().cpu().numpy()
                reconstruction_slice = x_hat[0, 0, slice_idx, :, :].detach().cpu().numpy()
                self.slice_plotter.plot_slices(original_slice, reconstruction_slice, 'Val')

        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-4)
        return optimizer

class MyDataset(CacheDataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform
        self.files = [f for f in os.listdir(data_dir) if f.endswith('.nrrd')]

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.data_dir, self.files[idx])
        data, header = nrrd.read(file_path)
        if self.transform:
            data = self.transform(data)
        return data, data

class PlotLossCallback(pl.Callback):
    def __init__(self, log_dir):
        super().__init__()
        self.writer = SummaryWriter(log_dir)

    def on_train_epoch_end(self, trainer, pl_module, **kwargs):
        epoch = trainer.current_epoch
        train_loss = trainer.callback_metrics['train_loss'].cpu().item()
        val_loss = trainer.callback_metrics['val_loss'].cpu().item()

        self.writer.add_scalars('AE SSIM Job 1 Loss', {'training': train_loss, 'validation': val_loss}, global_step=epoch + 1)
        time_spent = time.time() - start_time
        
        print(f"Time Spent {time_spent:.2f}")
        print(f"Epoch: {epoch + 1}")
    def on_train_end(self, trainer, pl_module):
        self.writer.close()

folder_path = "./Models"
if not os.path.exists(folder_path):
        os.makedirs(folder_path)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    dirpath= folder_path,
    filename='AE_SSIM{epoch}.pth',
    save_last=True,
    verbose=True,
    every_n_epochs=200
)

transform = Compose([
    Lambda(func=lambda x: np.expand_dims(x, 0) if x.ndim == 3 else x),
    RandSpatialCrop((256, 256, 256), random_size=False),
    RandRotate90(prob=0.5),
    ScaleIntensityRange(a_min=-1310, a_max=3310, b_min=-1, b_max=1, clip=True),  # Normalize between -1 and 1
    ToTensor(dtype=torch.float32)
])
start_time = time.time()
device = torch.device("cuda" if torch.cuda.is_available() else "gpu")

train_data_dir = "../../train70"
val_data_dir = "../../val30"

train_dataset_uc = MyDataset(train_data_dir, transform)
val_dataset_uc   = MyDataset(val_data_dir  , transform)

train_dataset = CacheDataset(train_dataset_uc, transform=transform, num_workers=0)
val_dataset   = CacheDataset(val_dataset_uc,   transform=transform, num_workers=0)

train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True,  num_workers=2)
val_dataloader   = DataLoader(val_dataset,   batch_size=1, shuffle=False, num_workers=2)

trainer = pl.Trainer(
    max_epochs=1500,
    callbacks=[PlotLossCallback("../../logs/"), checkpoint_callback],
    profiler='simple'
)
# Out:
# Loading dataset:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading dataset:  50%|█████     | 1/2 [00:03<00:03,  3.71s/it]
# Loading dataset: 100%|██████████| 2/2 [00:07<00:00,  3.58s/it]
# Loading dataset: 100%|██████████| 2/2 [00:07<00:00,  3.60s/it]
# Loading dataset:   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset: 100%|██████████| 1/1 [00:03<00:00,  3.54s/it]
# Loading dataset: 100%|██████████| 1/1 [00:03<00:00,  3.54s/it]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
# Initialize model and start training
model = AutoEncoderModel()
trainer.fit(model, train_dataloader, val_dataloader)
torch.save(model.state_dict(), folder_path + '/aeSSIM.pth')
# Out:
# /old_Users/tgafrick/RA4/.venvE/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:653: Checkpoint directory /old_Users/tgafrick/RA4/jobs/job5/Models exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   | Name          | Type        | Params
# ----------------------------------------------
# 0 | autoencoder   | AutoEncoder | 6.5 M
# 1 | loss_function | SSIMLoss    | 0
# ----------------------------------------------
# 6.5 M     Trainable params
# 0         Non-trainable params
# 6.5 M     Total params
# 25.892    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /old_Users/tgafrick/RA4/.venvE/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (2) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Time Spent 33.96
# Epoch: 0
# Validation: |          | 0/? [00:00<?, ?it/s]
# Time Spent 50.06
# Epoch: 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Time Spent 65.39
# Epoch: 2
# Validation: |          | 0/? [00:00<?, ?it/s]
# Time Spent 80.67
# Epoch: 3
# Validation: |          | 0/? [00:00<?, ?it/s]
# Time Spent 96.04
# Epoch: 4
# `Trainer.fit` stopped: `max_epochs=5` reached.
# FIT Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                           	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                            	|  -              	|  782            	|  84.458         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                               	|  14.731         	|  5              	|  73.653         	|  87.207         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                   	|  2.953          	|  16             	|  47.248         	|  55.943         	|
# |  [LightningModule]AutoEncoderModel.transfer_batch_to_device                                                                                                       	|  2.9528         	|  16             	|  47.245         	|  55.939         	|
# |  run_training_batch                                                                                                                                               	|  0.82158        	|  10             	|  8.2158         	|  9.7276         	|
# |  [LightningModule]AutoEncoderModel.optimizer_step                                                                                                                 	|  0.8211         	|  10             	|  8.211          	|  9.722          	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                   	|  1.2257         	|  6              	|  7.3545         	|  8.7078         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_train_epoch_end       	|  1.1262         	|  5              	|  5.6312         	|  6.6675         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                     	|  0.44517        	|  10             	|  4.4517         	|  5.2709         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                          	|  0.34397        	|  10             	|  3.4397         	|  4.0727         	|
# |  [_EvaluationLoop].val_next                                                                                                                                       	|  0.50154        	|  6              	|  3.0093         	|  3.563          	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                       	|  0.25707        	|  10             	|  2.5707         	|  3.0437         	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                    	|  0.017971       	|  6              	|  0.10782        	|  0.12767        	|
# |  [LightningModule]AutoEncoderModel.optimizer_zero_grad                                                                                                            	|  0.0086949      	|  10             	|  0.086949       	|  0.10295        	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                  	|  0.032957       	|  1              	|  0.032957       	|  0.039022       	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                     	|  0.002332       	|  10             	|  0.02332        	|  0.027612       	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                         	|  0.01875        	|  1              	|  0.01875        	|  0.0222         	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                   	|  0.0026726      	|  5              	|  0.013363       	|  0.015822       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                              	|  0.0020693      	|  6              	|  0.012416       	|  0.0147         	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                              	|  0.010827       	|  1              	|  0.010827       	|  0.012819       	|
# |  [Callback]PlotLossCallback.on_train_epoch_end                                                                                                                    	|  0.0021539      	|  5              	|  0.010769       	|  0.012751       	|
# |  [LightningModule]AutoEncoderModel.on_validation_model_eval                                                                                                       	|  0.0016684      	|  6              	|  0.01001        	|  0.011852       	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                      	|  0.001271       	|  6              	|  0.0076263      	|  0.0090297      	|
# |  [LightningModule]AutoEncoderModel.on_validation_model_zero_grad                                                                                                  	|  0.00089159     	|  5              	|  0.0044579      	|  0.0052783      	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                	|  0.00074121     	|  6              	|  0.0044473      	|  0.0052657      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.setup                    	|  0.0024591      	|  1              	|  0.0024591      	|  0.0029116      	|
# |  [Callback]PlotLossCallback.on_train_end                                                                                                                          	|  0.0019331      	|  1              	|  0.0019331      	|  0.0022889      	|
# |  [LightningModule]AutoEncoderModel.configure_optimizers                                                                                                           	|  0.0017647      	|  1              	|  0.0017647      	|  0.0020894      	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                           	|  0.0014531      	|  1              	|  0.0014531      	|  0.0017205      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                     	|  0.00021454     	|  5              	|  0.0010727      	|  0.0012701      	|
# |  [LightningModule]AutoEncoderModel.configure_gradient_clipping                                                                                                    	|  5.2778e-05     	|  10             	|  0.00052778     	|  0.0006249      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_validation_end        	|  7.9469e-05     	|  6              	|  0.00047681     	|  0.00056456     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_train_batch_end       	|  3.3668e-05     	|  10             	|  0.00033668     	|  0.00039864     	|
# |  [LightningModule]AutoEncoderModel.on_before_batch_transfer                                                                                                       	|  1.1564e-05     	|  16             	|  0.00018503     	|  0.00021908     	|
# |  [Callback]PlotLossCallback.on_after_backward                                                                                                                     	|  8.1683e-06     	|  10             	|  8.1683e-05     	|  9.6714e-05     	|
# |  [Callback]PlotLossCallback.on_validation_start                                                                                                                   	|  1.3388e-05     	|  6              	|  8.0327e-05     	|  9.5109e-05     	|
# |  [Callback]PlotLossCallback.on_train_batch_start                                                                                                                  	|  7.9862e-06     	|  10             	|  7.9862e-05     	|  9.4558e-05     	|
# |  [Callback]PlotLossCallback.on_train_epoch_start                                                                                                                  	|  1.5207e-05     	|  5              	|  7.6034e-05     	|  9.0026e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                       	|  1.0286e-05     	|  6              	|  6.1715e-05     	|  7.3072e-05     	|
# |  [Callback]PlotLossCallback.on_before_zero_grad                                                                                                                   	|  5.6694e-06     	|  10             	|  5.6694e-05     	|  6.7127e-05     	|
# |  [LightningModule]AutoEncoderModel.on_validation_epoch_start                                                                                                      	|  9.1485e-06     	|  6              	|  5.4891e-05     	|  6.4992e-05     	|
# |  [LightningModule]AutoEncoderModel.on_validation_batch_start                                                                                                      	|  9.1466e-06     	|  6              	|  5.488e-05      	|  6.4979e-05     	|
# |  [LightningModule]AutoEncoderModel.on_after_batch_transfer                                                                                                        	|  3.4143e-06     	|  16             	|  5.4628e-05     	|  6.4681e-05     	|
# |  [LightningModule]AutoEncoderModel.on_train_batch_start                                                                                                           	|  5.4218e-06     	|  10             	|  5.4218e-05     	|  6.4195e-05     	|
# |  [Callback]PlotLossCallback.on_train_batch_end                                                                                                                    	|  4.7852e-06     	|  10             	|  4.7852e-05     	|  5.6658e-05     	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                        	|  4.6892e-06     	|  10             	|  4.6892e-05     	|  5.5521e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                               	|  7.8095e-06     	|  6              	|  4.6857e-05     	|  5.548e-05      	|
# |  [Callback]PlotLossCallback.on_fit_end                                                                                                                            	|  4.605e-05      	|  1              	|  4.605e-05      	|  5.4524e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                              	|  4.2797e-06     	|  10             	|  4.2797e-05     	|  5.0672e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                      	|  8.406e-06      	|  5              	|  4.203e-05      	|  4.9764e-05     	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                      	|  4.0829e-06     	|  10             	|  4.0829e-05     	|  4.8342e-05     	|
# |  [Callback]PlotLossCallback.on_before_optimizer_step                                                                                                              	|  3.6862e-06     	|  10             	|  3.6862e-05     	|  4.3645e-05     	|
# |  [LightningModule]AutoEncoderModel.on_after_backward                                                                                                              	|  3.5415e-06     	|  10             	|  3.5415e-05     	|  4.1932e-05     	|
# |  [Callback]PlotLossCallback.on_before_backward                                                                                                                    	|  3.4323e-06     	|  10             	|  3.4323e-05     	|  4.0639e-05     	|
# |  [LightningModule]AutoEncoderModel.on_before_zero_grad                                                                                                            	|  3.3822e-06     	|  10             	|  3.3822e-05     	|  4.0046e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_after_backward        	|  3.3811e-06     	|  10             	|  3.3811e-05     	|  4.0033e-05     	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                         	|  3.24e-06       	|  10             	|  3.24e-05       	|  3.8363e-05     	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                 	|  5.2118e-06     	|  6              	|  3.1271e-05     	|  3.7025e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_train_batch_start     	|  3.0877e-06     	|  10             	|  3.0877e-05     	|  3.6559e-05     	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                      	|  2.9448e-06     	|  10             	|  2.9448e-05     	|  3.4867e-05     	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                   	|  2.8851e-06     	|  10             	|  2.8851e-05     	|  3.416e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_validation_start      	|  4.6729e-06     	|  6              	|  2.8038e-05     	|  3.3197e-05     	|
# |  [Callback]PlotLossCallback.on_validation_batch_start                                                                                                             	|  4.6535e-06     	|  6              	|  2.7921e-05     	|  3.3059e-05     	|
# |  [LightningModule]AutoEncoderModel.on_before_optimizer_step                                                                                                       	|  2.5866e-06     	|  10             	|  2.5866e-05     	|  3.0626e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_train_epoch_start     	|  5.0867e-06     	|  5              	|  2.5433e-05     	|  3.0113e-05     	|
# |  [Callback]PlotLossCallback.on_validation_epoch_start                                                                                                             	|  4.1767e-06     	|  6              	|  2.506e-05      	|  2.9672e-05     	|
# |  [Callback]PlotLossCallback.on_validation_end                                                                                                                     	|  4.1275e-06     	|  6              	|  2.4765e-05     	|  2.9323e-05     	|
# |  [LightningModule]AutoEncoderModel.on_train_epoch_start                                                                                                           	|  4.9217e-06     	|  5              	|  2.4608e-05     	|  2.9137e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                              	|  4.0451e-06     	|  6              	|  2.4271e-05     	|  2.8737e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                         	|  4.0107e-06     	|  6              	|  2.4064e-05     	|  2.8493e-05     	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                   	|  3.9099e-06     	|  6              	|  2.3459e-05     	|  2.7776e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_before_optimizer_step 	|  2.3405e-06     	|  10             	|  2.3405e-05     	|  2.7712e-05     	|
# |  [Callback]PlotLossCallback.on_validation_epoch_end                                                                                                               	|  3.8155e-06     	|  6              	|  2.2893e-05     	|  2.7106e-05     	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                  	|  2.26e-06       	|  10             	|  2.26e-05       	|  2.6759e-05     	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                               	|  2.2421e-06     	|  10             	|  2.2421e-05     	|  2.6547e-05     	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                    	|  2.2084e-06     	|  10             	|  2.2084e-05     	|  2.6147e-05     	|
# |  [Callback]PlotLossCallback.on_train_start                                                                                                                        	|  2.208e-05      	|  1              	|  2.208e-05      	|  2.6143e-05     	|
# |  [Callback]PlotLossCallback.on_validation_batch_end                                                                                                               	|  3.6785e-06     	|  6              	|  2.2071e-05     	|  2.6132e-05     	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                       	|  2.1583e-06     	|  10             	|  2.1583e-05     	|  2.5555e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_before_zero_grad      	|  2.1385e-06     	|  10             	|  2.1385e-05     	|  2.532e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_validation_epoch_start	|  3.5281e-06     	|  6              	|  2.1169e-05     	|  2.5064e-05     	|
# |  [LightningModule]AutoEncoderModel.on_train_batch_end                                                                                                             	|  2.0742e-06     	|  10             	|  2.0742e-05     	|  2.4559e-05     	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                        	|  2.0638e-06     	|  10             	|  2.0638e-05     	|  2.4436e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_before_backward       	|  2.047e-06      	|  10             	|  2.047e-05      	|  2.4237e-05     	|
# |  [LightningModule]AutoEncoderModel.setup                                                                                                                          	|  2.047e-05      	|  1              	|  2.047e-05      	|  2.4237e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                 	|  3.3018e-06     	|  6              	|  1.9811e-05     	|  2.3457e-05     	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                     	|  1.9794e-06     	|  10             	|  1.9794e-05     	|  2.3437e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                        	|  3.8376e-06     	|  5              	|  1.9188e-05     	|  2.2719e-05     	|
# |  [LightningModule]AutoEncoderModel.on_validation_start                                                                                                            	|  2.9719e-06     	|  6              	|  1.7831e-05     	|  2.1112e-05     	|
# |  [Callback]PlotLossCallback.on_save_checkpoint                                                                                                                    	|  3.4156e-06     	|  5              	|  1.7078e-05     	|  2.0221e-05     	|
# |  [LightningModule]AutoEncoderModel.on_before_backward                                                                                                             	|  1.6879e-06     	|  10             	|  1.6879e-05     	|  1.9985e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_validation_batch_start	|  2.7162e-06     	|  6              	|  1.6297e-05     	|  1.9296e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                    	|  1.4986e-05     	|  1              	|  1.4986e-05     	|  1.7744e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_validation_batch_end  	|  2.2587e-06     	|  6              	|  1.3552e-05     	|  1.6046e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                  	|  1.2493e-05     	|  1              	|  1.2493e-05     	|  1.4792e-05     	|
# |  [LightningModule]AutoEncoderModel.on_validation_batch_end                                                                                                        	|  1.8937e-06     	|  6              	|  1.1362e-05     	|  1.3453e-05     	|
# |  [Callback]PlotLossCallback.setup                                                                                                                                 	|  1.116e-05      	|  1              	|  1.116e-05      	|  1.3214e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                	|  1.8326e-06     	|  6              	|  1.0996e-05     	|  1.3019e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_validation_epoch_end  	|  1.7792e-06     	|  6              	|  1.0675e-05     	|  1.2639e-05     	|
# |  [LightningModule]AutoEncoderModel.on_validation_end                                                                                                              	|  1.7768e-06     	|  6              	|  1.0661e-05     	|  1.2623e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                   	|  1.6917e-06     	|  6              	|  1.015e-05      	|  1.2018e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_fit_start             	|  9.9931e-06     	|  1              	|  9.9931e-06     	|  1.1832e-05     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                     	|  9.9801e-06     	|  1              	|  9.9801e-06     	|  1.1817e-05     	|
# |  [Callback]PlotLossCallback.on_sanity_check_start                                                                                                                 	|  9.53e-06       	|  1              	|  9.53e-06       	|  1.1284e-05     	|
# |  [Callback]PlotLossCallback.on_fit_start                                                                                                                          	|  9.327e-06      	|  1              	|  9.327e-06      	|  1.1043e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                     	|  1.8115e-06     	|  5              	|  9.0573e-06     	|  1.0724e-05     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                        	|  1.7506e-06     	|  5              	|  8.7528e-06     	|  1.0363e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_save_checkpoint       	|  1.7356e-06     	|  5              	|  8.6781e-06     	|  1.0275e-05     	|
# |  [LightningModule]AutoEncoderModel.on_validation_epoch_end                                                                                                        	|  1.433e-06      	|  6              	|  8.598e-06      	|  1.018e-05      	|
# |  [LightningModule]AutoEncoderModel.on_train_start                                                                                                                 	|  8.567e-06      	|  1              	|  8.567e-06      	|  1.0144e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                 	|  1.417e-06      	|  6              	|  8.5018e-06     	|  1.0066e-05     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                              	|  8.2371e-06     	|  1              	|  8.2371e-06     	|  9.7529e-06     	|
# |  [LightningModule]AutoEncoderModel.on_train_epoch_end                                                                                                             	|  1.6356e-06     	|  5              	|  8.1779e-06     	|  9.6829e-06     	|
# |  [Callback]PlotLossCallback.teardown                                                                                                                              	|  7.407e-06      	|  1              	|  7.407e-06      	|  8.7701e-06     	|
# |  [LightningModule]AutoEncoderModel.on_save_checkpoint                                                                                                             	|  1.2822e-06     	|  5              	|  6.4112e-06     	|  7.591e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_sanity_check_start    	|  5.4231e-06     	|  1              	|  5.4231e-06     	|  6.4211e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_fit_end               	|  5.37e-06       	|  1              	|  5.37e-06       	|  6.3582e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                             	|  5.167e-06      	|  1              	|  5.167e-06      	|  6.1178e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                           	|  4.977e-06      	|  1              	|  4.977e-06      	|  5.8929e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.teardown                 	|  4.947e-06      	|  1              	|  4.947e-06      	|  5.8573e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                                     	|  4.9141e-06     	|  1              	|  4.9141e-06     	|  5.8184e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                               	|  4.8901e-06     	|  1              	|  4.8901e-06     	|  5.79e-06       	|
# |  [LightningModule]AutoEncoderModel.configure_callbacks                                                                                                            	|  4.828e-06      	|  1              	|  4.828e-06      	|  5.7164e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                	|  4.78e-06       	|  1              	|  4.78e-06       	|  5.6596e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_train_end             	|  4.7302e-06     	|  1              	|  4.7302e-06     	|  5.6006e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                    	|  4.729e-06      	|  1              	|  4.729e-06      	|  5.5993e-06     	|
# |  [LightningModule]AutoEncoderModel.on_train_end                                                                                                                   	|  4.638e-06      	|  1              	|  4.638e-06      	|  5.4915e-06     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                            	|  4.5612e-06     	|  1              	|  4.5612e-06     	|  5.4005e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                  	|  4.5002e-06     	|  1              	|  4.5002e-06     	|  5.3283e-06     	|
# |  [LightningModule]AutoEncoderModel.teardown                                                                                                                       	|  4.4829e-06     	|  1              	|  4.4829e-06     	|  5.3079e-06     	|
# |  [LightningModule]AutoEncoderModel.on_fit_end                                                                                                                     	|  4.0762e-06     	|  1              	|  4.0762e-06     	|  4.8263e-06     	|
# |  [LightningModule]AutoEncoderModel.on_fit_start                                                                                                                   	|  4.0361e-06     	|  1              	|  4.0361e-06     	|  4.7788e-06     	|
# |  [Callback]PlotLossCallback.on_sanity_check_end                                                                                                                   	|  3.7819e-06     	|  1              	|  3.7819e-06     	|  4.4778e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_train_start           	|  3.7448e-06     	|  1              	|  3.7448e-06     	|  4.434e-06      	|
# |  [LightningModule]AutoEncoderModel.prepare_data                                                                                                                   	|  3.7302e-06     	|  1              	|  3.7302e-06     	|  4.4166e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                      	|  3.0701e-06     	|  1              	|  3.0701e-06     	|  3.6351e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                       	|  1.9649e-06     	|  1              	|  1.9649e-06     	|  2.3264e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 200, 'train_time_interval': None}.on_sanity_check_end      	|  1.7011e-06     	|  1              	|  1.7011e-06     	|  2.0141e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
